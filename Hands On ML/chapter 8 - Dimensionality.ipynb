# %%
print("Hello world")
# Out:
# Hello world

# %%
import pandas as pd
import os
import numpy as np

pwd = os.getcwd()
filepath = os.path.join(pwd, "creditcard.csv")

dataset = pd.read_csv(filepath)
dataset
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
dropped_cols = dataset[["Time", "Amount"]]

y = dataset["Class"]
X = dataset.iloc[:, 1:-2]
X
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V19       V20  \
# 0       0.239599  0.098698  0.363787  0.090794  ...  0.403993  0.251412
# 1      -0.078803  0.085102 -0.255425 -0.166974  ... -0.145783 -0.069083
# 2       0.791461  0.247676 -1.514654  0.207643  ... -2.261857  0.524980
# 3       0.237609  0.377436 -1.387024 -0.054952  ... -1.232622 -0.208038
# 4       0.592941 -0.270533  0.817739  0.753074  ...  0.803487  0.408542
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -4.918215  7.305334  1.914428  4.356170  ... -0.682920  1.475829
# 284803  0.024330  0.294869  0.584800 -0.975926  ... -1.545556  0.059616
# 284804 -0.296827  0.708417  0.432454 -0.484782  ... -0.577252  0.001396
# 284805 -0.686180  0.679145  0.392087 -0.399126  ...  2.897849  0.127434
# 284806  1.577006 -0.414650  0.486180 -0.915427  ... -0.256117  0.382948
#
#              V21       V22       V23       V24       V25       V26       V27  \
# 0      -0.018307  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558
# 1      -0.225775 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983
# 2       0.247998  0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353
# 3      -0.108300  0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723
# 4      -0.009431  0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  0.213454  0.111864  1.014480 -0.509348  1.436807  0.250034  0.943651
# 284803  0.214205  0.924384  0.012463 -1.016226 -0.606624 -0.395255  0.068472
# 284804  0.232045  0.578229 -0.037501  0.640134  0.265745 -0.087371  0.004455
# 284805  0.265245  0.800049 -0.163298  0.123205 -0.569159  0.546668  0.108821
# 284806  0.261057  0.643078  0.376777  0.008797 -0.473649 -0.818267 -0.002415
#
#              V28
# 0      -0.021053
# 1       0.014724
# 2      -0.059752
# 3       0.061458
# 4       0.215153
# ...          ...
# 284802  0.823731
# 284803 -0.053527
# 284804 -0.026561
# 284805  0.104533
# 284806  0.013649
#
# [284807 rows x 28 columns]

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=10) #n_comps = how many dimensions we want

X_10D = pca.fit_transform(X)
X_10D = pd.DataFrame(X_10D)
X_10D
# Out:
#                 0          1         2         3         4         5  \
# 0        1.359751   0.072819 -2.536454  1.377892  0.338498  0.462372
# 1       -1.191523  -0.265770 -0.167815  0.448942 -0.062446 -0.084412
# 2        1.358485   1.341755 -1.774984  0.374106  0.506209  1.808666
# 3        0.966452   0.185927 -1.792832 -0.864539  0.008558  1.245002
# 4        1.157584  -0.878560 -1.545072  0.401322  0.411329  0.099363
# ...           ...        ...       ...       ...       ...       ...
# 284802  11.881651 -10.069496  9.830393 -2.072231  5.366143 -2.599144
# 284803   0.732655   0.055918 -2.033382 -0.742612 -0.866345  1.060925
# 284804  -1.919810   0.300769  3.249713 -0.557494 -2.628714  3.032958
# 284805   0.240344  -0.530564 -0.702361  0.689992  0.378279  0.623144
# 284806   0.533102   0.189643 -0.701745 -0.508611  0.015848 -0.644620
#
#                6         7         8         9
# 0       0.240400 -0.093559  0.373190 -0.069678
# 1      -0.083867 -0.103645 -0.271137  0.134127
# 2       0.796297 -0.208947 -1.483347 -0.169750
# 3       0.246175 -0.371745 -1.368191  0.041880
# 4       0.606089  0.303848  0.862318 -0.673827
# ...          ...       ...       ...       ...
# 284802 -4.912152 -7.288438  2.076929 -4.241315
# 284803  0.040289 -0.263282  0.589032  1.098765
# 284804 -0.298767 -0.701092  0.409031  0.487207
# 284805 -0.685338 -0.678325  0.381101  0.409666
# 284806  1.582361  0.436262  0.463185  0.978367
#
# [284807 rows x 10 columns]

# %%
X_inv = pca.inverse_transform(X_10D)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 X_inv = pca.inverse_transform(X_10D)
#
# File c:\Users\Admin\anaconda3\Lib\site-packages\sklearn\decomposition\_base.py:159, in _BasePCA.inverse_transform(self, X)
#     151     return (
#     152         np.dot(
#     153             X,
#    (...)
#     156         + self.mean_
#     157     )
#     158 else:
# --> 159     return np.dot(X, self.components_) + self.mean_
#
# File <__array_function__ internals>:200, in dot(*args, **kwargs)
#
# ValueError: shapes (284807,10) and (28,28) not aligned: 10 (dim 1) != 28 (dim 0)

# %%
pca = PCA() #n_comps = how many dimensions we want

XD= pca.fit(X)
cum_sum = np.cumsum(pca.explained_variance_ratio_)

d = np.argmax(cum_sum >= 0.95)
d
# Out:
# 21

# %%
len(cum_sum)
# Out:
# 28

# %%
import matplotlib.pyplot as plt

plt.plot(cum_sum)

# %%
# Out:
#                 0          1         2         3         4         5  \
# 0        1.359751   0.072819 -2.536454  1.377892  0.338498  0.462372
# 1       -1.191523  -0.265770 -0.167815  0.448942 -0.062446 -0.084412
# 2        1.358485   1.341755 -1.774984  0.374106  0.506209  1.808666
# 3        0.966452   0.185927 -1.792832 -0.864539  0.008558  1.245002
# 4        1.157584  -0.878560 -1.545072  0.401322  0.411329  0.099363
# ...           ...        ...       ...       ...       ...       ...
# 284802  11.881651 -10.069496  9.830393 -2.072231  5.366143 -2.599144
# 284803   0.732655   0.055918 -2.033382 -0.742612 -0.866345  1.060925
# 284804  -1.919810   0.300769  3.249713 -0.557494 -2.628714  3.032958
# 284805   0.240344  -0.530564 -0.702361  0.689992  0.378279  0.623144
# 284806   0.533102   0.189643 -0.701745 -0.508611  0.015848 -0.644620
#
#                6         7         8         9
# 0       0.240400 -0.093559  0.373190 -0.069678
# 1      -0.083867 -0.103645 -0.271137  0.134127
# 2       0.796297 -0.208947 -1.483347 -0.169750
# 3       0.246175 -0.371745 -1.368191  0.041880
# 4       0.606089  0.303848  0.862318 -0.673827
# ...          ...       ...       ...       ...
# 284802 -4.912152 -7.288438  2.076929 -4.241315
# 284803  0.040289 -0.263282  0.589032  1.098765
# 284804 -0.298767 -0.701092  0.409031  0.487207
# 284805 -0.685338 -0.678325  0.381101  0.409666
# 284806  1.582361  0.436262  0.463185  0.978367
#
# [284807 rows x 10 columns]
